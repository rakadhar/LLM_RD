# %% [markdown]
# # YOUR FIRST LAB
# ### Please read this section. This is valuable to get you prepared, even if it's a long read -- it's important stuff.
#
# ## Your first Frontier LLM Project
#
# Let's build a useful LLM solution - in a matter of minutes.
#
# By the end of this course, you will have built an autonomous Agentic AI solution with 7 agents that collaborate to solve a business problem. All in good time! We will start with something smaller...
#
# Our goal is to code a new kind of Web Browser. Give it a URL, and it will respond with a summary. The Reader's Digest of the internet!!
#
# Before starting, you should have completed the setup for [PC](../SETUP-PC.md) or [Mac](../SETUP-mac.md) and you hopefully launched this jupyter lab from within the project root directory, with your environment activated.
#
# ## If you're new to Jupyter Lab
#
# Welcome to the wonderful world of Data Science experimentation! Once you've used Jupyter Lab, you'll wonder how you ever lived without it. Simply click in each "cell" with code in it, such as the cell immediately below this text, and hit Shift+Return to execute that cell. As you wish, you can add a cell with the + button in the toolbar, and print values of variables, or try out variations.
#
# I've written a notebook called [Guide to Jupyter](Guide%20to%20Jupyter.ipynb) to help you get more familiar with Jupyter Labs, including adding Markdown comments, using `!` to run shell commands, and `tqdm` to show progress.
#
# ## If you're new to the Command Line
#
# Please see these excellent guides: [Command line on PC](https://chatgpt.com/share/67b0acea-ba38-8012-9c34-7a2541052665) and [Command line on Mac](https://chatgpt.com/canvas/shared/67b0b10c93a081918210723867525d2b).
#
# ## If you'd prefer to work in IDEs
#
# If you're more comfortable in IDEs like VSCode or Pycharm, they both work great with these lab notebooks too.
# If you'd prefer to work in VSCode, [here](https://chatgpt.com/share/676f2e19-c228-8012-9911-6ca42f8ed766) are instructions from an AI friend on how to configure it for the course.
#
# ## If you'd like to brush up your Python
#
# I've added a notebook called [Intermediate Python](Intermediate%20Python.ipynb) to get you up to speed. But you should give it a miss if you already have a good idea what this code does:
# `yield from {book.get("author") for book in books if book.get("author")}`
#
# ## I am here to help
#
# If you have any problems at all, please do reach out.
# I'm available through the platform, or at ed@edwarddonner.com, or at https://www.linkedin.com/in/eddonner/ if you'd like to connect (and I love connecting!)
# And this is new to me, but I'm also trying out X/Twitter at [@edwarddonner](https://x.com/edwarddonner) - if you're on X, please show me how it's done 😂
#
# ## More troubleshooting
#
# Please see the [troubleshooting](troubleshooting.ipynb) notebook in this folder to diagnose and fix common problems. At the very end of it is a diagnostics script with some useful debug info.
#
# ## If this is old hat!
#
# If you're already comfortable with today's material, please hang in there; you can move swiftly through the first few labs - we will get much more in depth as the weeks progress.
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Please read - important note</h2>
#             <span style="color:#900;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations. If you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...</span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Treat these labs as a resource</h2>
#             <span style="color:#f71;">I push updates to the code regularly. When people ask questions or have problems, I incorporate it in the code, adding more examples or improved commentary. As a result, you'll notice that the code below isn't identical to the videos. Everything from the videos is here; but in addition, I've added more steps and better explanations, and occasionally added new models like DeepSeek. Consider this like an interactive book that accompanies the lectures.
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business value of these exercises</h2>
#             <span style="color:#181;">A final thought. While I've designed these notebooks to be educational, I've also tried to make them enjoyable. We'll do fun things like have LLMs tell jokes and argue with each other. But fundamentally, my goal is to teach skills you can apply in business. I'll explain business implications as we go, and it's worth keeping this in mind: as you build experience with models and techniques, think of ways you could put this into action at work today. Please do contact me if you'd like to discuss more or if you have ideas to bounce off me.</span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
from openai import OpenAI
print("hello")

# If you get an error running this cell, then please head over to the troubleshooting notebook!
# Out:
# hello

# %% [markdown]
# # Connecting to OpenAI
#
# The next cell is where we load in the environment variables in your `.env` file and connect to OpenAI.
#
# ## Troubleshooting if you have problems:
#
# Head over to the [troubleshooting](troubleshooting.ipynb) notebook in this folder for step by step code to identify the root cause and fix it!
#
# If you make a change, try restarting the "Kernel" (the python process sitting behind this notebook) by Kernel menu >> Restart Kernel and Clear Outputs of All Cells. Then try this notebook again, starting at the top.
#
# Or, contact me! Message me or email ed@edwarddonner.com and we will get this to work.
#
# Any concerns about API costs? See my notes in the README - costs should be minimal, and you can control it at every point. You can also use Ollama as a free alternative, which we discuss during Day 2.

# %%
# Load environment variables in a file called .env

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
openai = OpenAI()

# If this doesn't work, try Kernel menu >> Restart Kernel and Clear Outputs Of All Cells, then run the cells from the top of this notebook down.
# If it STILL doesn't work (horrors!) then please see the Troubleshooting notebook in this folder for full instructions

# %% [markdown]
# # Let's make a quick call to a Frontier model to get started, as a preview!

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, GPT! This is my first ever message to you! Hi!"
response = openai.chat.completions.create(model="gpt-4o-mini", messages=[{"role":"user", "content":message}])
print(response.choices[0].message.content)
# Out:
# Hello! Welcome! I'm glad you're here. How can I assist you today?

# %% [markdown]
# ## OK onwards with our first project

# %%
# A class to represent a Webpage
# If you're not familiar with Classes, check out the "Intermediate Python" notebook

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:

    def __init__(self, url):
        """
        Create this Website object from the given url using the BeautifulSoup library
        """
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
# Let's try one out. Change the website and add print statements to follow along.

cms = Website("https://www.cms.gov/medicare/quality/nursing-home-improvement/quality-measures")
print(cms.title)
print(cms.text)
# Out:
# Quality Measures | CMS
# Skip to main content
# Centers for Medicare & Medicaid Services
# CMS Newsroom
# Header
# About CMS
# Newsroom
# Data & Research
# Search CMS.gov
# Search
# Search
# Popular terms
# Physician Fee Schedule
# Local Coverage Determination
# Medically Unlikely Edits
# Telehealth
# Covid-19
# CMS.gov main menu
# Medicare
# Back to main menu
# section title h2
# Enrollment & renewal
# Back to
# menu
# section title h3
# Original Medicare (Part A and B) Eligibility and Enrollment
# Annual Medicare Participation Announcement
# Providers & suppliers
# Medicare Managed Care Eligibility and Enrollment
# Part D Eligibility and Enrollment
# Health plans
# Coverage
# Back to
# menu
# section title h3
# Coverage Determination Process
# Medicare Coverage Database
# Approved facilities, trials, & registries
# Telehealth
# Medicare Summary Notice
# Prescription drug coverage contracting
# Coverage with evidence development
# Investigational device exemption studies
# Prescription drug coverage
# Drug coverage claims data
# Dental coverage
# Preventive Services
# Medicare Coverage Center
# End Stage Renal Disease (ESRD) Center
# Ambulances Services Center
# Regulations & guidance
# Back to
# menu
# section title h3
# Manuals
# Transmittals
# CMS Records Schedule
# Medicare Fee-for-Service payment regulations
# National Provider Identifier Standard (NPI)
# Advisory committees
# Legislation
# Promoting Interoperability Programs
# CMS rulemaking
# CMS Hearing Officer
# Office of the Attorney Advisor (OAA)
# Provider Reimbursement Review Board (PRRB)
# Medicare Geographic Classification Review Board (MGCRB)
# Physician Self-Referral
# Quarterly provider updates
# E-Prescribing
# Coding & billing
# Back to
# menu
# section title h3
# Place of service codes
# ICD-10 codes
# Healthcare Common Procedure Coding System (HCPCS)
# Integrated Outpatient Code Editor
# National Correct Coding Initiative (NCCI) edits
# NCCI for Medicaid
# Electronic billing
# Medicare Administrative Contractors (MACs)
# Provider Customer Service Program
# Skilled Nursing Facility (SNF) consolidated billing
# Roster billing
# Therapy services
# Medicare claims & public health emergencies
# Guide for Medical Technology Companies and Other Interested Parties
# Payment
# Back to
# menu
# section title h3
# Medicare Part B Drug Average Sales Price
# All Fee-For-Service-Providers
# Fee schedules
# Prospective Payment Systems
# Opioid Treatment Programs (OTP)
# Covid-19 Vaccine Toolkit
# Bankruptcy
# Sustainable Growth Rates & Conversion Factors
# Medicare Advantage Rates & Statistics
# Medicare-Medicaid coordination
# Back to
# menu
# section title h3
# Qualified Medicare beneficiary program
# Resources
# Qualified Medicare beneficiary program
# Spotlight
# Events
# Financial alignment initiative
# Initiative to reduce avoidable hospitalizations
# Reports & Guidance
# Program of All-Inclusive Care for the Elderly (PACE)
# Reporting Fraud
# Resources for Medicare-Medicaid plans
# Resources for state Medicaid agencies
# Healthcare Fraud Prevention Partnership
# Clinical Templates
# Appeals & grievances
# Back to
# menu
# section title h3
# Original Medicare appeals
# Managed Care appeals & grievances
# Medicare Prescription drug appeals & grievances
# Ombudsman Center
# Appeals Decision Search (Part C & Part D)
# Quality
# Back to
# menu
# section title h3
# Value-based programs
# Person & Family Engagement
# Quality improvement organizations
# Nursing home quality improvement
# Inpatient Rehabilitation Facility (IRF) Quality Reporting Program (QRP)
# Home Health Quality Reporting Program
# ESRD Quality Incentive Program
# CMS National Quality Strategy
# Hospice Quality Reporting Program
# Long-Term Care Hospital (LTCH) Quality Reporting Program (QRP)
# Appropriate Use Criteria Program
# Quality measures
# Medicare Advantage quality improvement program
# Physician compare initiative
# Quality initiatives
# Part C and D Performance Data
# Skilled Nursing Facility (SNF) Quality Reporting Program (QRP)
# Health & safety standards
# Back to
# menu
# section title h3
# Clinical Laboratory Improvement Amendments (CLIA)
# Quality, Safety & Oversight Group (QSOG)
# Quality, safety & oversight general information
# Accreditation programs
# Emergency preparedness
# Certification & compliance
# Enforcement
# Regulations, Certification, & Compliance
# Conditions for coverage & participation
# Employers & plan sponsors
# Back to
# menu
# section title h3
# Creditable coverage
# IC-Placeholder-1
# Audits & Compliance
# Back to
# menu
# section title h3
# Part A cost report audit
# Part C/Part D compliance & audits
# Forms & notices
# Back to
# menu
# section title h3
# CMS forms
# CMS forms list
# Beneficiary Notices Initiative (BNI)
# Health & drug plans
# Back to
# menu
# section title h3
# Plan payment
# Plan payment data
# Medical loss ratio
# Coverage Gap Discount Program
# Managed care marketing
# Medicare Advantage application
# Medigap (Medicare supplement health insurance)
# Medical Savings Account (MSA)
# Private Fee-for-Service Plans
# Health Care Prepayment Plans (HCPPs)
# Cost plans
# Special needs plans
# Network adequacy
# Coordination of benefits & recovery
# Back to
# menu
# section title h3
# Overview
# Mandatory Insurer Reporting for Group Health Plans (GHP)
# Mandatory insurer reporting (NGHP)
# Workers' comp Medicare set aside arrangements
# Attorney services
# Beneficiary services
# COBA Trading Partners
# Employer services
# Insurer services
# Prescription drug assistance programs
# Provider services
# Settlements
# Back to
# menu
# section title h3
# Jimmo Settlement
# Ryan Settlement
# Medicaid/CHIP
# Back to main menu
# section title h2
# What is Medicaid?
# Back to
# menu
# section title h3
# Visit Medicaid.gov
# View Medicaid maps
# Visit CHIP.gov
# Medicare-Medicaid Coordination
# Back to
# menu
# section title h3
# Integrated care resources
# Initiative to reduce avoidable hospitalizations
# Financial alignment initiative
# Medicaid Integrity Institute
# RG-Placeholder-1
# IC-Placeholder-2
# Marketplace & Private Insurance
# Back to main menu
# section title h2
# About the Marketplace
# Back to
# menu
# section title h3
# Marketplace oversight
# Affordable Care Act
# Overview of the exchanges
# Exchange coverage maps
# Medicare and the Marketplace
# Private Health Insurance
# Back to
# menu
# section title h3
# Patient’s Bill of Rights
# Medical loss ratio
# Annual limits
# Review of insurance rates
# Market rating
# Self-funded, non-federal governmental plans
# Grandfathered plans
# Health Reimbursement Arrangements
# Coverage for young adults
# Student health plans
# Mental health parity and addiction equity
# Prevention
# Consumer protections & enforcement
# Pre-existing condition insurance plan
# Qualifying Health Coverage (QHC)
# RG-Placeholder-2
# In-person assisters
# Back to
# menu
# section title h3
# Information for Partners
# Assister outreach & education
# Applications, forms, & notices
# Assister programs & procedures
# Assister technical resources
# Assister training & webinars
# Agents & Brokers
# Back to
# menu
# section title h3
# Resources for Agent & Brokers
# Registration & training
# Open enrollment
# Direct enrollment partners
# General resources
# Video Learning Center
# Agent & Broker FAQ
# Marketplace help desk & call centers
# Registration Completion List
# Marketplace Registration Tracker
# AB Suspension & Termination List
# Find local help
# Issuer and direct enrollment partner directory
# Help on demand
# SHOP Resources
# Health Plans & Issuers
# Back to
# menu
# section title h3
# Qualified health plan certification
# Summary of benefits & coverage
# Insurance programs
# Premium stabilization programs
# Health insurance market reforms
# Minimum essential coverage
# Drug pricing & rebate review
# Employers & sponsors
# Back to
# menu
# section title h3
# Coverage
# Regulation & guidance
# Small business tax credit & premium assistance
# Appeals
# Small Business Health Options Program (SHOP)
# Early retiree reinsurance program
# Employer initiatives
# States
# Back to
# menu
# section title h3
# Planning & establishing a Marketplace
# Territory cooperative agreements
# Early innovator program
# State flexibility to stabilize the Market
# Exchange establishment grants
# Pre-existing condition insurance plan
# Resources
# Back to
# menu
# section title h3
# About Us
# Data resources
# Letters
# Regulations & Guidance
# Training resources
# Marketplace Coverage Transitions
# Initiatives
# Back to main menu
# section title h2
# Burden Reduction
# Back to
# menu
# section title h3
# Overview
# E-health
# Back to
# menu
# section title h3
# Overview
# Flu
# Back to
# menu
# section title h3
# Overview
# Health Equity
# Back to
# menu
# section title h3
# Coverage to Care
# Minority health
# Cobertura de atención
# Grants & awards
# Healthplan price transparency
# Back to
# menu
# section title h3
# Overview
# Hospital price transparency
# Back to
# menu
# section title h3
# Overview
# Innovation Center
# Back to
# menu
# section title h3
# Overview
# About
# Key Concepts
# Model Data
# Value-Based Care Spotlight
# Innovation Models
# Where Innovation is Happening
# Evaluations & Research Reports
# Lookup tools
# Back to
# menu
# section title h3
# Overview
# Marketplace Open Enrollment
# Back to
# menu
# section title h3
# Overview
# Maternal Health
# Back to
# menu
# section title h3
# Overview
# Medicare OE partner resources
# Back to
# menu
# section title h3
# Overview
# Medicare Open Enrollment
# Back to
# menu
# section title h3
# Overview
# Nursing Home Careers
# Back to
# menu
# section title h3
# Overview
# Open Payments
# Back to
# menu
# section title h3
# Overview
# Opioids
# Back to
# menu
# section title h3
# Overview
# Your Patient Rights
# Back to
# menu
# section title h3
# Emergency Room Rights
# Medical bill rights
# Training & Education
# Back to main menu
# section title h2
# CMS National Training Program
# Back to
# menu
# section title h3
# National Training Program resources
# Class modules
# Partner outreach resources
# Back to
# menu
# section title h3
# Partner with CMS
# National Medicare Education Program (NMEP)
# Low-Income Subsidy (LIS) outreach
# Become a champion for coverage
# Faith-Based Partners
# Rural Health Partners
# American Indian/Alaska Native
# Partnering with CMS Center
# Medicare Learning Network® (MLN)
# Back to
# menu
# section title h3
# Resources & training
# Newsletter
# Compliance
# Partnerships
# CMS Open Door Forums
# Back to
# menu
# section title h3
# About Open Door Forums
# Ambulance
# End-Stage Renal Disease (ESRD) Dialysis Facility Care Compare
# Home Health, Hospice & Durable Medical Equipment (DME)
# Hospital
# Long-Term Services & Supports
# Physicians, Nurses and Allied Health Professionals
# Rural Health
# Skilled Nursing Facilities (SNFs)/Long-Term Care
# Special Open Door forums
# Look up topics
# Back to
# menu
# section title h3
# Medicare
# Medicaid
# CHIP
# American Indian/Alaska Native Center
# Quality of care
# Special populations
# Fraud & abuse
# States
# Privacy
# Health conditions & campaigns
# New Medicare Card
# HIPAA Administrative Simplification
# Learn More
# Back to
# menu
# section title h3
# Attend events
# Find resources
# Get training
# Find tools to help you help others
# Get digital media
# Find your provider type
# Back to
# menu
# section title h3
# Physicians & other health professionals
# Facilities
# Health & drug plans
# Employers & unions
# Medicare
# Quality
# Nursing home quality improvement
# Quality Measures
# Quality Measures
# Pages in this section
# Nursing home quality improvement
# NHQI Spotlight & Announcements
# Quality Measures
# Minimum Data Set for Nursing Homes and Swing Bed Providers
# Resident Assessment Instrument Manual
# Minimum Data Set Technical Information
# Value-Based Purchasing (SNF VBP) Program
# Staffing Data Submission PBJ
# Care Compare
# Archived: Quality Measures
# Archived: MDS 3.0 RAI Manuals
# Archived: MDS 3.0 Technical Information
# Archived: MDS 3.0 Training
# Archived: MDS 2.0 for Nursing Homes
# Care Compare
# Quality Measures
# Now available! Our new
# Provider Data Catalog
# (PDC) makes it easier for you to search and download our publicly reported data. We’ve also improved
# Medicare’s compare sites
# .
# What's New
# December 23, 2024
# MDS 3.0 Quality Measures User's Manual v17.0 and Accompanying Risk Adjustment Appendix File – Now Available
# The Minimum Data Set (MDS) 3.0 Quality Measures (QM) User’s Manual Version (V)17.0 is now available. The MDS 3.0 QM User’s Manual V17.0 contains detailed specifications for the MDS 3.0 QMs and includes a Notable Changes section that summarizes the major changes from MDS 3.0 QM User’s Manual V16.0.
# Changes include the revision of guidance on the selection of MDS Section GG item columns to clarify that Section GG item values are determined by the target and/or prior assessment’s qualifying reason for assessment (RFA) and additional guidance on which GG item column to select when the target and/or prior assessment has more than one qualifying RFA. The updated guidance will not have a significant impact on measure calculations.
# The Risk Adjustment Appendix File for the MDS 3.0 Quality Measures User’s Manual accompanies the MDS 3.0 QM Manual v17.0 and contains the logistic regression coefficient values used to calculate the risk-adjusted quality measures that are included in the Nursing Home Quality Initiative (NHQI), effective January 1, 2025. Note that there are no coefficient changes to the Risk Adjustment Appendix File from v16.0 to v17.0 since specification updates did not significantly change the coefficient values.
# The full MDS 3.0 QM User’s Manual V17.0 and accompanying Risk Adjustment Appendix File can be found in the
# Downloads
# section of this webpage.
# July 1, 2024
# MDS 3.0 QM User’s Manual Version 16.0 Risk Adjustment Appendix File – Now Available
# The Minimum Data Set (MDS) 3.0 Quality Measures (QM) User’s Manual V16.0 Risk Adjustment Appendix File is now available. The Risk-Adjustment Appendix File for the MDS 3.0 Quality Measures User’s Manual accompanies the MDS 3.0 QM Manual Version 16 and contains the logistic regression coefficient values used to calculate the risk-adjusted quality measures that are included in the Nursing Home Quality Initiative (NHQI), effective October 1, 2023.
# Changes encompassed in the appendix include:
# The removal of the national average and coefficient values for the Percent of Residents who Made Improvements in Function (Short Stay) (CMS ID: N037.03) measure, as it was retired from the NHQI effective October 1, 2023; and
# The addition of the national average and coefficient values for the new Percent of Residents with Pressure Ulcers (Long Stay) (CMS ID: N045.01) and the Percent of Residents with New or Worsened Bowel or Bladder Incontinence (Long Stay) (CMS ID: N046.01) measures, implemented in the NHQI effective October 1, 2023.
# The latest national averages and coefficient values for the new and existing risk-adjusted NHQI measures in this appendix were calculated using MDS data submitted for 2024 Quarter 1.
# A new .zip file (MDS 3.0 QM Manual v16.0 Effective 10-1-2023 and Associated User Manual Files Update.zip) containing the v16 Risk Adjustment Appendix is available under the
# Downloads
# section of this webpage. This file includes a complete set of the latest user manual files for nursing home quality measures:
# MDS 3.0 QM User’s Manual V16.0
# (MDS-3.0-QM-USERS-MANUAL-v16.pdf) contains detailed specifications for the MDS 3.0 quality measures, as well as the Quality Measure Reporting Module Table that documents CMS quality measures calculated using MDS 3.0 data and reported in a CMS reporting module.
# Risk Adjustment Appendix File for MDS 3.0 QM User’s Manual V16.0
# (Risk-Adjustment-Appendix-File-for-MDS-3.0-Quality-Measures-User's-Manual-V16.xlsx) contains the logistic regression coefficients used for risk adjustment.
# Nursing Home Compare Claims-based Quality Measure Technical Specifications
# (Nursing Home Compare Claims-based Measures Tech Specs 2023 Update 03-20-2023.pdf) contains detailed technical specifications for all Nursing Home Claims-based Quality Measures.
# Nursing Home Compare Quality Measures Technical Specifications Appendix
# (APPENDIX - Claims-based Measures Technical Specifications Updates 03-20-23.pdf) contains tables and appendices related to the Nursing Home Compare Claims-based Quality Measures.
# Skilled Nursing Facility Quality Reporting Program (SNF QRP) Measure Calculations and Reporting User’s Manual V5.0
# (snf-qm-calculations-and-reporting-users-manual-v5.0.pdf) contains detailed specifications for all SNF QRP Quality Measures effective October 1, 2023.
# Risk Adjustment Appendix File for the SNF QRP Measure’s Calculations and Reporting User’s Manual V5.0
# (Risk-Adjustment-Appendix-File-for-SNF-Effective-10-01-2023.xlsx) contains risk-adjustment values used to calculate SNF QRP risk-adjusted quality measures.
# September 21, 2023
# Public Reporting Timeline for NHQI Measures Impacted by the MDS 3.0 G-GG Transition
# Effective October 1, 2023, Minimum Data Set (MDS) Section G:
# Functional Status
# will be replaced with Section GG:
# Functional Abilities and Goals
# . This transition will significantly impact the specifications of the following Nursing Home Quality Initiative (NHQI) Quality Measures (QMs):
# Percentage of Residents Who Made Improvements in Function (Short Stay)
# Percent of Residents Whose Need for Help with Activities of Daily Living Has Increased (Long Stay)
# Percent of Residents Whose Ability to Move Independently Worsened (Long Stay)
# Percent of High-Risk Residents with Pressure Ulcers (Long Stay)
# Percent of Low-Risk Residents Who Lose Control of Their Bowel and Bladder (Long Stay)
# To address the impact of this Section G to GG transition on the 2024 Nursing Home Care Compare public reporting schedule, the Centers for Medicare & Medicaid Services (CMS) will freeze (hold constant) the aforementioned QMs on Nursing Home Care Compare in April 2024. In October 2024, CMS will replace the Percentage of Residents Who Made Improvements in Function (Short Stay) measure with the new Discharge Function Score measure which was finalized in the
# FY2024 SNF PPS Final Rule
# for use in the Skilled Nursing Facility (SNF) Quality Reporting Program (QRP) and the SNF Value Based Purchasing (VBP) program. The remaining four measures will continue to be frozen until January 2025 while the data for the equivalent measures are collected.
# Please see the
# Updates to Nursing Home Care Compare Staffing and Quality Measures
# Quality, Safety & Oversight Group (QSO) memo for more information.
# For more information on the new and re-specified QMs please see the MDS 3.0 QM User’s Manual V16.0, which can be found in the
# Downloads
# section of this webpage.
# The current nursing home quality measures are:
# Short Stay Quality Measures
# Percent of Short-Stay Residents Who Were Re-Hospitalized after a Nursing Home Admission
# Percent of Short-Stay Residents Who Have Had an Outpatient Emergency Department Visit
# Percent of Residents Who Newly Received an Antipsychotic Medication
# Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury
# Percent of Residents Who Were Assessed and Appropriately Given the Seasonal Influenza Vaccine
# Percent of Residents Who Received the Seasonal Influenza Vaccine*
# Percent of Residents Who Were Offered and Declined the Seasonal Influenza Vaccine*
# Percent of Residents Who Did Not Receive, Due to Medical Contraindication, the Seasonal Influenza Vaccine*
# Percent of Residents Who Were Assessed and Appropriately Given the Pneumococcal Vaccine
# Percent of Residents Who Received the Pneumococcal Vaccine*
# Percent of Residents Who Were Offered and Declined the Pneumococcal Vaccine*
# Percent of Residents Who Did Not Receive, Due to Medical Contraindication, the Pneumococcal Vaccine*
# Discharge Function Score
# * These measures are not publicly reported but available for provider preview.
# Long Stay Quality Measures
# Number of Hospitalizations per 1,000 Long-Stay Resident Days
# Number of Outpatient Emergency Department Visits per 1,000 Long-Stay Resident Days
# Percent of Residents Who Received an Antipsychotic Medication
# Percent of Residents Experiencing One or More Falls with Major Injury
# Percent of High-Risk Residents with Pressure Ulcers
# Percent of Residents with a Urinary Tract Infection
# Percent of Residents Who Have or Had a Catheter Inserted and Left in Their Bladder
# Percent of Residents Whose Ability to Walk Independently Worsened
# Percent of Residents Whose Need for Help with Activities of Daily Living Has Increased
# Percent of Residents Assessed and Appropriately Given the Seasonal Influenza Vaccine
# Percent of Residents Who Received the Seasonal Influenza Vaccine*
# Percent of Residents Who Were Offered and Declined the Seasonal Influenza Vaccine*
# Percent of Residents Who Did Not Receive, Due to Medical Contraindication, the Seasonal Influenza Vaccine*
# Percent of Residents Assessed and Appropriately Given the Pneumococcal Vaccine
# Percent of Residents Who Received the Pneumococcal Vaccine*
# Percent of Residents Who Were Offered and Declined the Pneumococcal Vaccine*
# Percent of Residents Who Did Not Receive, Due to Medical Contraindication, the Pneumococcal Vaccine*
# Percent of Residents Who Were Physically Restrained
# Percent of Low-Risk Residents Who Lose Control of Their Bowels or Bladder
# Percent of Residents Who Lose Too Much Weight
# Percent of Residents Who Have Depressive Symptoms
# Percent of Residents Who Used Antianxiety or Hypnotic Medication
# Percent of Residents with Pressure Ulcers
# Percent of Residents with New ore Worsened Bowel or Bladder Incontinence
# * These measures are not publicly reported but available for provider preview.
# Quality measure specifications are available in the QM Users’ Manual download file, which can be found under the
# Downloads
# section below. A sub-group of quality measures are incorporated into the Five-Star Quality Rating System and used to determine scoring for the quality measures domain on Nursing Home Compare.
# Downloads
# MDS-3.0-QM-USERS-MANUAL-v17.0 (PDF)
# Risk-Adjustment-Appendix-File-for-MDS-3.0-Quality-Measures-Users-Manual-V17 (XLSX)
# mds-qm-users-manual-v16.0_effective-10-1-2023-and-associated-user-manuals-updated (ZIP)
# Related Links
# Five-Star Quality Rating System
# Page Last Modified:
# 01/16/2025 10:36 AM
# Help with File Formats and Plug-Ins
# Get email updates
# Sign up to get the latest information about your choice of CMS topics. You can decide how often to receive updates.
# Email
# Sign up - opens in a new window
# Sign up
# CMS & HHS Websites
# CMS & HHS Websites
# Medicare.gov
# Medicaid.gov
# InsureKidsNow.gov
# HealthCare.gov
# HHS.gov
# HHS.gov/Open
# About CMS
# About CMS
# About Us
# Careers
# Newsroom
# Tools
# Tools
# Acronyms
# Archive
# Contacts
# Glossary
# Helpful Links
# Helpful Links
# Privacy Policy
# Plain Language
# Privacy Settings
# Nondiscrimination & Accessibility
# Developer Information
# Vulnerability Disclosure Policy
# USA Government Sites
# USA Government Sites
# Freedom of Information Act
# No Fear Act
# Inspector General
# USA.gov
# Connect with CMS
# Linkedin link
# Youtube link
# Facebook link
# Twitter link
# RSS Feed link
# A federal government website managed and paid for by the U.S. Centers for Medicare & Medicaid Services.
# 7500 Security Boulevard, Baltimore, MD 21244

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT4o have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
# A function that writes a User Prompt that asks for summaries of websites:

def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
print(user_prompt_for(cms))
# Out:
# You are looking at a website titled Quality Measures | CMS
# The contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.
#
# Skip to main content
# Centers for Medicare & Medicaid Services
# CMS Newsroom
# Header
# About CMS
# Newsroom
# Data & Research
# Search CMS.gov
# Search
# Search
# Popular terms
# Physician Fee Schedule
# Local Coverage Determination
# Medically Unlikely Edits
# Telehealth
# Covid-19
# CMS.gov main menu
# Medicare
# Back to main menu
# section title h2
# Enrollment & renewal
# Back to
# menu
# section title h3
# Original Medicare (Part A and B) Eligibility and Enrollment
# Annual Medicare Participation Announcement
# Providers & suppliers
# Medicare Managed Care Eligibility and Enrollment
# Part D Eligibility and Enrollment
# Health plans
# Coverage
# Back to
# menu
# section title h3
# Coverage Determination Process
# Medicare Coverage Database
# Approved facilities, trials, & registries
# Telehealth
# Medicare Summary Notice
# Prescription drug coverage contracting
# Coverage with evidence development
# Investigational device exemption studies
# Prescription drug coverage
# Drug coverage claims data
# Dental coverage
# Preventive Services
# Medicare Coverage Center
# End Stage Renal Disease (ESRD) Center
# Ambulances Services Center
# Regulations & guidance
# Back to
# menu
# section title h3
# Manuals
# Transmittals
# CMS Records Schedule
# Medicare Fee-for-Service payment regulations
# National Provider Identifier Standard (NPI)
# Advisory committees
# Legislation
# Promoting Interoperability Programs
# CMS rulemaking
# CMS Hearing Officer
# Office of the Attorney Advisor (OAA)
# Provider Reimbursement Review Board (PRRB)
# Medicare Geographic Classification Review Board (MGCRB)
# Physician Self-Referral
# Quarterly provider updates
# E-Prescribing
# Coding & billing
# Back to
# menu
# section title h3
# Place of service codes
# ICD-10 codes
# Healthcare Common Procedure Coding System (HCPCS)
# Integrated Outpatient Code Editor
# National Correct Coding Initiative (NCCI) edits
# NCCI for Medicaid
# Electronic billing
# Medicare Administrative Contractors (MACs)
# Provider Customer Service Program
# Skilled Nursing Facility (SNF) consolidated billing
# Roster billing
# Therapy services
# Medicare claims & public health emergencies
# Guide for Medical Technology Companies and Other Interested Parties
# Payment
# Back to
# menu
# section title h3
# Medicare Part B Drug Average Sales Price
# All Fee-For-Service-Providers
# Fee schedules
# Prospective Payment Systems
# Opioid Treatment Programs (OTP)
# Covid-19 Vaccine Toolkit
# Bankruptcy
# Sustainable Growth Rates & Conversion Factors
# Medicare Advantage Rates & Statistics
# Medicare-Medicaid coordination
# Back to
# menu
# section title h3
# Qualified Medicare beneficiary program
# Resources
# Qualified Medicare beneficiary program
# Spotlight
# Events
# Financial alignment initiative
# Initiative to reduce avoidable hospitalizations
# Reports & Guidance
# Program of All-Inclusive Care for the Elderly (PACE)
# Reporting Fraud
# Resources for Medicare-Medicaid plans
# Resources for state Medicaid agencies
# Healthcare Fraud Prevention Partnership
# Clinical Templates
# Appeals & grievances
# Back to
# menu
# section title h3
# Original Medicare appeals
# Managed Care appeals & grievances
# Medicare Prescription drug appeals & grievances
# Ombudsman Center
# Appeals Decision Search (Part C & Part D)
# Quality
# Back to
# menu
# section title h3
# Value-based programs
# Person & Family Engagement
# Quality improvement organizations
# Nursing home quality improvement
# Inpatient Rehabilitation Facility (IRF) Quality Reporting Program (QRP)
# Home Health Quality Reporting Program
# ESRD Quality Incentive Program
# CMS National Quality Strategy
# Hospice Quality Reporting Program
# Long-Term Care Hospital (LTCH) Quality Reporting Program (QRP)
# Appropriate Use Criteria Program
# Quality measures
# Medicare Advantage quality improvement program
# Physician compare initiative
# Quality initiatives
# Part C and D Performance Data
# Skilled Nursing Facility (SNF) Quality Reporting Program (QRP)
# Health & safety standards
# Back to
# menu
# section title h3
# Clinical Laboratory Improvement Amendments (CLIA)
# Quality, Safety & Oversight Group (QSOG)
# Quality, safety & oversight general information
# Accreditation programs
# Emergency preparedness
# Certification & compliance
# Enforcement
# Regulations, Certification, & Compliance
# Conditions for coverage & participation
# Employers & plan sponsors
# Back to
# menu
# section title h3
# Creditable coverage
# IC-Placeholder-1
# Audits & Compliance
# Back to
# menu
# section title h3
# Part A cost report audit
# Part C/Part D compliance & audits
# Forms & notices
# Back to
# menu
# section title h3
# CMS forms
# CMS forms list
# Beneficiary Notices Initiative (BNI)
# Health & drug plans
# Back to
# menu
# section title h3
# Plan payment
# Plan payment data
# Medical loss ratio
# Coverage Gap Discount Program
# Managed care marketing
# Medicare Advantage application
# Medigap (Medicare supplement health insurance)
# Medical Savings Account (MSA)
# Private Fee-for-Service Plans
# Health Care Prepayment Plans (HCPPs)
# Cost plans
# Special needs plans
# Network adequacy
# Coordination of benefits & recovery
# Back to
# menu
# section title h3
# Overview
# Mandatory Insurer Reporting for Group Health Plans (GHP)
# Mandatory insurer reporting (NGHP)
# Workers' comp Medicare set aside arrangements
# Attorney services
# Beneficiary services
# COBA Trading Partners
# Employer services
# Insurer services
# Prescription drug assistance programs
# Provider services
# Settlements
# Back to
# menu
# section title h3
# Jimmo Settlement
# Ryan Settlement
# Medicaid/CHIP
# Back to main menu
# section title h2
# What is Medicaid?
# Back to
# menu
# section title h3
# Visit Medicaid.gov
# View Medicaid maps
# Visit CHIP.gov
# Medicare-Medicaid Coordination
# Back to
# menu
# section title h3
# Integrated care resources
# Initiative to reduce avoidable hospitalizations
# Financial alignment initiative
# Medicaid Integrity Institute
# RG-Placeholder-1
# IC-Placeholder-2
# Marketplace & Private Insurance
# Back to main menu
# section title h2
# About the Marketplace
# Back to
# menu
# section title h3
# Marketplace oversight
# Affordable Care Act
# Overview of the exchanges
# Exchange coverage maps
# Medicare and the Marketplace
# Private Health Insurance
# Back to
# menu
# section title h3
# Patient’s Bill of Rights
# Medical loss ratio
# Annual limits
# Review of insurance rates
# Market rating
# Self-funded, non-federal governmental plans
# Grandfathered plans
# Health Reimbursement Arrangements
# Coverage for young adults
# Student health plans
# Mental health parity and addiction equity
# Prevention
# Consumer protections & enforcement
# Pre-existing condition insurance plan
# Qualifying Health Coverage (QHC)
# RG-Placeholder-2
# In-person assisters
# Back to
# menu
# section title h3
# Information for Partners
# Assister outreach & education
# Applications, forms, & notices
# Assister programs & procedures
# Assister technical resources
# Assister training & webinars
# Agents & Brokers
# Back to
# menu
# section title h3
# Resources for Agent & Brokers
# Registration & training
# Open enrollment
# Direct enrollment partners
# General resources
# Video Learning Center
# Agent & Broker FAQ
# Marketplace help desk & call centers
# Registration Completion List
# Marketplace Registration Tracker
# AB Suspension & Termination List
# Find local help
# Issuer and direct enrollment partner directory
# Help on demand
# SHOP Resources
# Health Plans & Issuers
# Back to
# menu
# section title h3
# Qualified health plan certification
# Summary of benefits & coverage
# Insurance programs
# Premium stabilization programs
# Health insurance market reforms
# Minimum essential coverage
# Drug pricing & rebate review
# Employers & sponsors
# Back to
# menu
# section title h3
# Coverage
# Regulation & guidance
# Small business tax credit & premium assistance
# Appeals
# Small Business Health Options Program (SHOP)
# Early retiree reinsurance program
# Employer initiatives
# States
# Back to
# menu
# section title h3
# Planning & establishing a Marketplace
# Territory cooperative agreements
# Early innovator program
# State flexibility to stabilize the Market
# Exchange establishment grants
# Pre-existing condition insurance plan
# Resources
# Back to
# menu
# section title h3
# About Us
# Data resources
# Letters
# Regulations & Guidance
# Training resources
# Marketplace Coverage Transitions
# Initiatives
# Back to main menu
# section title h2
# Burden Reduction
# Back to
# menu
# section title h3
# Overview
# E-health
# Back to
# menu
# section title h3
# Overview
# Flu
# Back to
# menu
# section title h3
# Overview
# Health Equity
# Back to
# menu
# section title h3
# Coverage to Care
# Minority health
# Cobertura de atención
# Grants & awards
# Healthplan price transparency
# Back to
# menu
# section title h3
# Overview
# Hospital price transparency
# Back to
# menu
# section title h3
# Overview
# Innovation Center
# Back to
# menu
# section title h3
# Overview
# About
# Key Concepts
# Model Data
# Value-Based Care Spotlight
# Innovation Models
# Where Innovation is Happening
# Evaluations & Research Reports
# Lookup tools
# Back to
# menu
# section title h3
# Overview
# Marketplace Open Enrollment
# Back to
# menu
# section title h3
# Overview
# Maternal Health
# Back to
# menu
# section title h3
# Overview
# Medicare OE partner resources
# Back to
# menu
# section title h3
# Overview
# Medicare Open Enrollment
# Back to
# menu
# section title h3
# Overview
# Nursing Home Careers
# Back to
# menu
# section title h3
# Overview
# Open Payments
# Back to
# menu
# section title h3
# Overview
# Opioids
# Back to
# menu
# section title h3
# Overview
# Your Patient Rights
# Back to
# menu
# section title h3
# Emergency Room Rights
# Medical bill rights
# Training & Education
# Back to main menu
# section title h2
# CMS National Training Program
# Back to
# menu
# section title h3
# National Training Program resources
# Class modules
# Partner outreach resources
# Back to
# menu
# section title h3
# Partner with CMS
# National Medicare Education Program (NMEP)
# Low-Income Subsidy (LIS) outreach
# Become a champion for coverage
# Faith-Based Partners
# Rural Health Partners
# American Indian/Alaska Native
# Partnering with CMS Center
# Medicare Learning Network® (MLN)
# Back to
# menu
# section title h3
# Resources & training
# Newsletter
# Compliance
# Partnerships
# CMS Open Door Forums
# Back to
# menu
# section title h3
# About Open Door Forums
# Ambulance
# End-Stage Renal Disease (ESRD) Dialysis Facility Care Compare
# Home Health, Hospice & Durable Medical Equipment (DME)
# Hospital
# Long-Term Services & Supports
# Physicians, Nurses and Allied Health Professionals
# Rural Health
# Skilled Nursing Facilities (SNFs)/Long-Term Care
# Special Open Door forums
# Look up topics
# Back to
# menu
# section title h3
# Medicare
# Medicaid
# CHIP
# American Indian/Alaska Native Center
# Quality of care
# Special populations
# Fraud & abuse
# States
# Privacy
# Health conditions & campaigns
# New Medicare Card
# HIPAA Administrative Simplification
# Learn More
# Back to
# menu
# section title h3
# Attend events
# Find resources
# Get training
# Find tools to help you help others
# Get digital media
# Find your provider type
# Back to
# menu
# section title h3
# Physicians & other health professionals
# Facilities
# Health & drug plans
# Employers & unions
# Medicare
# Quality
# Nursing home quality improvement
# Quality Measures
# Quality Measures
# Pages in this section
# Nursing home quality improvement
# NHQI Spotlight & Announcements
# Quality Measures
# Minimum Data Set for Nursing Homes and Swing Bed Providers
# Resident Assessment Instrument Manual
# Minimum Data Set Technical Information
# Value-Based Purchasing (SNF VBP) Program
# Staffing Data Submission PBJ
# Care Compare
# Archived: Quality Measures
# Archived: MDS 3.0 RAI Manuals
# Archived: MDS 3.0 Technical Information
# Archived: MDS 3.0 Training
# Archived: MDS 2.0 for Nursing Homes
# Care Compare
# Quality Measures
# Now available! Our new
# Provider Data Catalog
# (PDC) makes it easier for you to search and download our publicly reported data. We’ve also improved
# Medicare’s compare sites
# .
# What's New
# December 23, 2024
# MDS 3.0 Quality Measures User's Manual v17.0 and Accompanying Risk Adjustment Appendix File – Now Available
# The Minimum Data Set (MDS) 3.0 Quality Measures (QM) User’s Manual Version (V)17.0 is now available. The MDS 3.0 QM User’s Manual V17.0 contains detailed specifications for the MDS 3.0 QMs and includes a Notable Changes section that summarizes the major changes from MDS 3.0 QM User’s Manual V16.0.
# Changes include the revision of guidance on the selection of MDS Section GG item columns to clarify that Section GG item values are determined by the target and/or prior assessment’s qualifying reason for assessment (RFA) and additional guidance on which GG item column to select when the target and/or prior assessment has more than one qualifying RFA. The updated guidance will not have a significant impact on measure calculations.
# The Risk Adjustment Appendix File for the MDS 3.0 Quality Measures User’s Manual accompanies the MDS 3.0 QM Manual v17.0 and contains the logistic regression coefficient values used to calculate the risk-adjusted quality measures that are included in the Nursing Home Quality Initiative (NHQI), effective January 1, 2025. Note that there are no coefficient changes to the Risk Adjustment Appendix File from v16.0 to v17.0 since specification updates did not significantly change the coefficient values.
# The full MDS 3.0 QM User’s Manual V17.0 and accompanying Risk Adjustment Appendix File can be found in the
# Downloads
# section of this webpage.
# July 1, 2024
# MDS 3.0 QM User’s Manual Version 16.0 Risk Adjustment Appendix File – Now Available
# The Minimum Data Set (MDS) 3.0 Quality Measures (QM) User’s Manual V16.0 Risk Adjustment Appendix File is now available. The Risk-Adjustment Appendix File for the MDS 3.0 Quality Measures User’s Manual accompanies the MDS 3.0 QM Manual Version 16 and contains the logistic regression coefficient values used to calculate the risk-adjusted quality measures that are included in the Nursing Home Quality Initiative (NHQI), effective October 1, 2023.
# Changes encompassed in the appendix include:
# The removal of the national average and coefficient values for the Percent of Residents who Made Improvements in Function (Short Stay) (CMS ID: N037.03) measure, as it was retired from the NHQI effective October 1, 2023; and
# The addition of the national average and coefficient values for the new Percent of Residents with Pressure Ulcers (Long Stay) (CMS ID: N045.01) and the Percent of Residents with New or Worsened Bowel or Bladder Incontinence (Long Stay) (CMS ID: N046.01) measures, implemented in the NHQI effective October 1, 2023.
# The latest national averages and coefficient values for the new and existing risk-adjusted NHQI measures in this appendix were calculated using MDS data submitted for 2024 Quarter 1.
# A new .zip file (MDS 3.0 QM Manual v16.0 Effective 10-1-2023 and Associated User Manual Files Update.zip) containing the v16 Risk Adjustment Appendix is available under the
# Downloads
# section of this webpage. This file includes a complete set of the latest user manual files for nursing home quality measures:
# MDS 3.0 QM User’s Manual V16.0
# (MDS-3.0-QM-USERS-MANUAL-v16.pdf) contains detailed specifications for the MDS 3.0 quality measures, as well as the Quality Measure Reporting Module Table that documents CMS quality measures calculated using MDS 3.0 data and reported in a CMS reporting module.
# Risk Adjustment Appendix File for MDS 3.0 QM User’s Manual V16.0
# (Risk-Adjustment-Appendix-File-for-MDS-3.0-Quality-Measures-User's-Manual-V16.xlsx) contains the logistic regression coefficients used for risk adjustment.
# Nursing Home Compare Claims-based Quality Measure Technical Specifications
# (Nursing Home Compare Claims-based Measures Tech Specs 2023 Update 03-20-2023.pdf) contains detailed technical specifications for all Nursing Home Claims-based Quality Measures.
# Nursing Home Compare Quality Measures Technical Specifications Appendix
# (APPENDIX - Claims-based Measures Technical Specifications Updates 03-20-23.pdf) contains tables and appendices related to the Nursing Home Compare Claims-based Quality Measures.
# Skilled Nursing Facility Quality Reporting Program (SNF QRP) Measure Calculations and Reporting User’s Manual V5.0
# (snf-qm-calculations-and-reporting-users-manual-v5.0.pdf) contains detailed specifications for all SNF QRP Quality Measures effective October 1, 2023.
# Risk Adjustment Appendix File for the SNF QRP Measure’s Calculations and Reporting User’s Manual V5.0
# (Risk-Adjustment-Appendix-File-for-SNF-Effective-10-01-2023.xlsx) contains risk-adjustment values used to calculate SNF QRP risk-adjusted quality measures.
# September 21, 2023
# Public Reporting Timeline for NHQI Measures Impacted by the MDS 3.0 G-GG Transition
# Effective October 1, 2023, Minimum Data Set (MDS) Section G:
# Functional Status
# will be replaced with Section GG:
# Functional Abilities and Goals
# . This transition will significantly impact the specifications of the following Nursing Home Quality Initiative (NHQI) Quality Measures (QMs):
# Percentage of Residents Who Made Improvements in Function (Short Stay)
# Percent of Residents Whose Need for Help with Activities of Daily Living Has Increased (Long Stay)
# Percent of Residents Whose Ability to Move Independently Worsened (Long Stay)
# Percent of High-Risk Residents with Pressure Ulcers (Long Stay)
# Percent of Low-Risk Residents Who Lose Control of Their Bowel and Bladder (Long Stay)
# To address the impact of this Section G to GG transition on the 2024 Nursing Home Care Compare public reporting schedule, the Centers for Medicare & Medicaid Services (CMS) will freeze (hold constant) the aforementioned QMs on Nursing Home Care Compare in April 2024. In October 2024, CMS will replace the Percentage of Residents Who Made Improvements in Function (Short Stay) measure with the new Discharge Function Score measure which was finalized in the
# FY2024 SNF PPS Final Rule
# for use in the Skilled Nursing Facility (SNF) Quality Reporting Program (QRP) and the SNF Value Based Purchasing (VBP) program. The remaining four measures will continue to be frozen until January 2025 while the data for the equivalent measures are collected.
# Please see the
# Updates to Nursing Home Care Compare Staffing and Quality Measures
# Quality, Safety & Oversight Group (QSO) memo for more information.
# For more information on the new and re-specified QMs please see the MDS 3.0 QM User’s Manual V16.0, which can be found in the
# Downloads
# section of this webpage.
# The current nursing home quality measures are:
# Short Stay Quality Measures
# Percent of Short-Stay Residents Who Were Re-Hospitalized after a Nursing Home Admission
# Percent of Short-Stay Residents Who Have Had an Outpatient Emergency Department Visit
# Percent of Residents Who Newly Received an Antipsychotic Medication
# Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury
# Percent of Residents Who Were Assessed and Appropriately Given the Seasonal Influenza Vaccine
# Percent of Residents Who Received the Seasonal Influenza Vaccine*
# Percent of Residents Who Were Offered and Declined the Seasonal Influenza Vaccine*
# Percent of Residents Who Did Not Receive, Due to Medical Contraindication, the Seasonal Influenza Vaccine*
# Percent of Residents Who Were Assessed and Appropriately Given the Pneumococcal Vaccine
# Percent of Residents Who Received the Pneumococcal Vaccine*
# Percent of Residents Who Were Offered and Declined the Pneumococcal Vaccine*
# Percent of Residents Who Did Not Receive, Due to Medical Contraindication, the Pneumococcal Vaccine*
# Discharge Function Score
# * These measures are not publicly reported but available for provider preview.
# Long Stay Quality Measures
# Number of Hospitalizations per 1,000 Long-Stay Resident Days
# Number of Outpatient Emergency Department Visits per 1,000 Long-Stay Resident Days
# Percent of Residents Who Received an Antipsychotic Medication
# Percent of Residents Experiencing One or More Falls with Major Injury
# Percent of High-Risk Residents with Pressure Ulcers
# Percent of Residents with a Urinary Tract Infection
# Percent of Residents Who Have or Had a Catheter Inserted and Left in Their Bladder
# Percent of Residents Whose Ability to Walk Independently Worsened
# Percent of Residents Whose Need for Help with Activities of Daily Living Has Increased
# Percent of Residents Assessed and Appropriately Given the Seasonal Influenza Vaccine
# Percent of Residents Who Received the Seasonal Influenza Vaccine*
# Percent of Residents Who Were Offered and Declined the Seasonal Influenza Vaccine*
# Percent of Residents Who Did Not Receive, Due to Medical Contraindication, the Seasonal Influenza Vaccine*
# Percent of Residents Assessed and Appropriately Given the Pneumococcal Vaccine
# Percent of Residents Who Received the Pneumococcal Vaccine*
# Percent of Residents Who Were Offered and Declined the Pneumococcal Vaccine*
# Percent of Residents Who Did Not Receive, Due to Medical Contraindication, the Pneumococcal Vaccine*
# Percent of Residents Who Were Physically Restrained
# Percent of Low-Risk Residents Who Lose Control of Their Bowels or Bladder
# Percent of Residents Who Lose Too Much Weight
# Percent of Residents Who Have Depressive Symptoms
# Percent of Residents Who Used Antianxiety or Hypnotic Medication
# Percent of Residents with Pressure Ulcers
# Percent of Residents with New ore Worsened Bowel or Bladder Incontinence
# * These measures are not publicly reported but available for provider preview.
# Quality measure specifications are available in the QM Users’ Manual download file, which can be found under the
# Downloads
# section below. A sub-group of quality measures are incorporated into the Five-Star Quality Rating System and used to determine scoring for the quality measures domain on Nursing Home Compare.
# Downloads
# MDS-3.0-QM-USERS-MANUAL-v17.0 (PDF)
# Risk-Adjustment-Appendix-File-for-MDS-3.0-Quality-Measures-Users-Manual-V17 (XLSX)
# mds-qm-users-manual-v16.0_effective-10-1-2023-and-associated-user-manuals-updated (ZIP)
# Related Links
# Five-Star Quality Rating System
# Page Last Modified:
# 01/16/2025 10:36 AM
# Help with File Formats and Plug-Ins
# Get email updates
# Sign up to get the latest information about your choice of CMS topics. You can decide how often to receive updates.
# Email
# Sign up - opens in a new window
# Sign up
# CMS & HHS Websites
# CMS & HHS Websites
# Medicare.gov
# Medicaid.gov
# InsureKidsNow.gov
# HealthCare.gov
# HHS.gov
# HHS.gov/Open
# About CMS
# About CMS
# About Us
# Careers
# Newsroom
# Tools
# Tools
# Acronyms
# Archive
# Contacts
# Glossary
# Helpful Links
# Helpful Links
# Privacy Policy
# Plain Language
# Privacy Settings
# Nondiscrimination & Accessibility
# Developer Information
# Vulnerability Disclosure Policy
# USA Government Sites
# USA Government Sites
# Freedom of Information Act
# No Fear Act
# Inspector General
# USA.gov
# Connect with CMS
# Linkedin link
# Youtube link
# Facebook link
# Twitter link
# RSS Feed link
# A federal government website managed and paid for by the U.S. Centers for Medicare & Medicaid Services.
# 7500 Security Boulevard, Baltimore, MD 21244

# %% [markdown]
# ## Messages
#
# The API from OpenAI expects to receive messages in a particular structure.
# Many of the other APIs share this structure:
#
# ```
# [
#     {"role": "system", "content": "system message goes here"},
#     {"role": "user", "content": "user message goes here"}
# ]
#
# To give you a preview, the next 2 cells make a rather simple call - we won't stretch the mighty GPT (yet!)

# %%
messages = [
    {"role": "system", "content": "You are a snarky assistant"},
    {"role": "user", "content": "What is 2 + 2?"}
]

# %%
# To give you a preview -- calling OpenAI with system and user messages:

response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
print(response.choices[0].message.content)
# Out:
# Oh wow, what a tough one! It's 4, in case you didn't have access to a calculator or fingers to count on.

# %% [markdown]
# ## And now let's build useful messages for GPT-4o-mini, using a function

# %%
# See how this function creates exactly the format above

def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
# Try this out, and then try for a few more websites

messages_for(cms)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown.'},
#  {'role': 'user',
#   'content': "You are looking at a website titled Quality Measures | CMS\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\nSkip to main content\nCenters for Medicare & Medicaid Services\nCMS Newsroom\nHeader\nAbout CMS\nNewsroom\nData & Research\nSearch CMS.gov\nSearch\nSearch\nPopular terms\nPhysician Fee Schedule\nLocal Coverage Determination\nMedically Unlikely Edits\nTelehealth\nCovid-19\nCMS.gov main menu\nMedicare\nBack to main menu\nsection title h2\nEnrollment & renewal\nBack to\nmenu\nsection title h3\nOriginal Medicare (Part A and B) Eligibility and Enrollment\nAnnual Medicare Participation Announcement\nProviders & suppliers\nMedicare Managed Care Eligibility and Enrollment\nPart D Eligibility and Enrollment\nHealth plans\nCoverage\nBack to\nmenu\nsection title h3\nCoverage Determination Process\nMedicare Coverage Database\nApproved facilities, trials, & registries\nTelehealth\nMedicare Summary Notice\nPrescription drug coverage contracting\nCoverage with evidence development\nInvestigational device exemption studies\nPrescription drug coverage\nDrug coverage claims data\nDental coverage\nPreventive Services\nMedicare Coverage Center\nEnd Stage Renal Disease (ESRD) Center\nAmbulances Services Center\nRegulations & guidance\nBack to\nmenu\nsection title h3\nManuals\nTransmittals\nCMS Records Schedule\nMedicare Fee-for-Service payment regulations\nNational Provider Identifier Standard (NPI)\nAdvisory committees\nLegislation\nPromoting Interoperability Programs\nCMS rulemaking\nCMS Hearing Officer\nOffice of the Attorney Advisor (OAA)\nProvider Reimbursement Review Board (PRRB)\nMedicare Geographic Classification Review Board (MGCRB)\nPhysician Self-Referral\nQuarterly provider updates\nE-Prescribing\nCoding & billing\nBack to\nmenu\nsection title h3\nPlace of service codes\nICD-10 codes\nHealthcare Common Procedure Coding System (HCPCS)\nIntegrated Outpatient Code Editor\nNational Correct Coding Initiative (NCCI) edits\nNCCI for Medicaid\nElectronic billing\nMedicare Administrative Contractors (MACs)\nProvider Customer Service Program\nSkilled Nursing Facility (SNF) consolidated billing\nRoster billing\nTherapy services\nMedicare claims & public health emergencies\nGuide for Medical Technology Companies and Other Interested Parties\nPayment\nBack to\nmenu\nsection title h3\nMedicare Part B Drug Average Sales Price\nAll Fee-For-Service-Providers\nFee schedules\nProspective Payment Systems\nOpioid Treatment Programs (OTP)\nCovid-19 Vaccine Toolkit\nBankruptcy\nSustainable Growth Rates & Conversion Factors\nMedicare Advantage Rates & Statistics\nMedicare-Medicaid coordination\nBack to\nmenu\nsection title h3\nQualified Medicare beneficiary program\nResources\nQualified Medicare beneficiary program\nSpotlight\nEvents\nFinancial alignment initiative\nInitiative to reduce avoidable hospitalizations\nReports & Guidance\nProgram of All-Inclusive Care for the Elderly (PACE)\nReporting Fraud\nResources for Medicare-Medicaid plans\nResources for state Medicaid agencies\nHealthcare Fraud Prevention Partnership\nClinical Templates\nAppeals & grievances\nBack to\nmenu\nsection title h3\nOriginal Medicare appeals\nManaged Care appeals & grievances\nMedicare Prescription drug appeals & grievances\nOmbudsman Center\nAppeals Decision Search (Part C & Part D)\nQuality\nBack to\nmenu\nsection title h3\nValue-based programs\nPerson & Family Engagement\nQuality improvement organizations\nNursing home quality improvement\nInpatient Rehabilitation Facility (IRF) Quality Reporting Program (QRP)\nHome Health Quality Reporting Program\nESRD Quality Incentive Program\nCMS National Quality Strategy\nHospice Quality Reporting Program\nLong-Term Care Hospital (LTCH) Quality Reporting Program (QRP)\nAppropriate Use Criteria Program\nQuality measures\nMedicare Advantage quality improvement program\nPhysician compare initiative\nQu ...

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
# And now: call the OpenAI API. You will get very familiar with this!

def summarize(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model = "gpt-4o-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://www.cms.gov/medicare/quality/nursing-home-improvement/quality-measures")
# Out:
# "# Quality Measures | CMS Summary\n\nThe **Quality Measures** section of the **Centers for Medicare & Medicaid Services (CMS)** website provides comprehensive information on quality measures used in various healthcare programs, particularly focusing on nursing home quality improvements. It includes resources like the Minimum Data Set (MDS), quality measure specifications, and updates regarding tools for quality assessment.\n\n## Key Components:\n- **Quality Measures Overview:** Detailed explanations and specifications for nursing home quality measures.\n- **MDS 3.0 Quality Measures User’s Manuals:** Access to user manuals outlining measures and reporting requirements, important for compliance and performance assessment.\n- **Public Reporting:** Information on how quality measures are reported and publicly disclosed, including scheduled updates and changes in measures.\n\n## Recent Announcements:\n1. **December 23, 2024:**\n   - Release of the MDS 3.0 Quality Measures User's Manual V17.0 and accompanying Risk Adjustment Appendix. This update includes detailed specifications and guidance for MDS quality measures.\n\n2. **July 1, 2024:**\n   - Availability of MDS 3.0 QM User’s Manual V16.0 and the associated Risk Adjustment Appendix File, noting changes in measures based on the data collected.\n\n3. **September 21, 2023:**\n   - Announcement regarding updates to quality measures following the transition from MDS Section G to Section GG, affecting several Nursing Home Quality Initiative measures. \n\nThe website also includes a **Downloads** section where users can find manuals and appendices that detail quality measures and provide important data for healthcare providers focusing on quality improvement initiatives."

# %%
# A function to display this nicely in the Jupyter output, using markdown

def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.cms.gov/medicare/quality/nursing-home-improvement/quality-measures")
# Out:
# # Summary of the Quality Measures | CMS Website
#
# The **Quality Measures** section of the **Centers for Medicare & Medicaid Services (CMS)** focuses on enhancing healthcare quality for beneficiaries through various reporting initiatives, guidelines, and programs.
#
# ### Key Content Areas:
# - **Quality Improvement Programs**: Information on programs like Nursing Home Quality Initiative (NHQI), Inpatient Rehabilitation Facility Quality Reporting Program, and Home Health Quality Reporting Program.
# - **Quality Measure Specifications**: Detailed guidance on Minimum Data Set (MDS) quality measures and updates to the measures used in public reporting.
# - **Resources for Providers**: Manuals, appendices, and technical specifications aimed at providers to assist in improving quality standards.
# - **Updates and Announcements**: Recent updates to quality measures and reporting, including adjustments to the MDS quality measures following changes in assessment protocols.
#
# ### Recent Announcements:
# 1. **MDS 3.0 Quality Measures User's Manual v17.0**: Released on December 23, 2024, providing detailed specifications and updates on quality measures.
#
# 2. **MDS 3.0 QM User's Manual Version 16.0**: Made available on July 1, 2024, with risk adjustment appendix and key changes noted.
#
# 3. **Public Reporting Timeline**: Effective October 1, 2023, significant updates to quality measures as the MDS Section G transitioned to Section GG, impacting the reporting and calculation of various quality metrics.
#
# ### Additional Features:
# - **Provider Data Catalog**: A new initiative to streamline access to reported data.
# - **Resources and Downloads**: Access to necessary manuals and appendices for quality measure implementation.
#
# This section aims to maintain and enhance the quality of care provided to Medicare recipients, encouraging participation and adherence to quality reporting standards among healthcare providers.

# %% [markdown]
# # Let's try more websites
#
# Note that this will only work on websites that can be scraped using this simplistic approach.
#
# Websites that are rendered with Javascript, like React apps, won't show up. See the community-contributions folder for a Selenium implementation that gets around this. You'll need to read up on installing Selenium (ask ChatGPT!)
#
# Also Websites protected with CloudFront (and similar) may give 403 errors - many thanks Andy J for pointing this out.
#
# But many websites will work just fine!

# %%
display_summary("https://www.cms.gov/medicare/health-safety-standards/certification-compliance/five-star-quality-rating-system")
# Out:
# # Five-Star Quality Rating System | CMS
#
# The **Five-Star Quality Rating System** was developed by the Centers for Medicare & Medicaid Services (CMS) to assist consumers, families, and caregivers in comparing nursing homes. It allows users to evaluate the quality of nursing homes based on a star rating system ranging from 1 to 5 stars, where 5 stars indicate much above average quality and 1 star indicates much below average quality. Ratings are provided for overall quality as well as for health inspections, staffing, and quality measures.
#
# ## Key Features:
# - **Overall Rating**: A single star rating reflecting the overall quality of each nursing home.
# - **Separate Ratings**: Additional ratings for health inspections, staffing levels, and quality measures.
# - Users are encouraged to utilize the rating system alongside other information sources, including personal visits to nursing homes.
#
# ## Recent Updates:
# - **January 18, 2023**: CMS announced adjustments to quality measure ratings based on erroneous schizophrenia coding, with audits planned for facilities that may have inaccuracies in their Minimum Data Set data.
# - **January 7, 2022**: New measures for nursing staff turnover and weekend staffing levels were added to the Care Compare website, set to impact the Five-Star Quality Rating System.
# - **December 4, 2020**: Announced updates to the Rating System, including resumption of health inspection and quality measure calculations starting January 27, 2021.
#
# For more detailed guidance, including the methods used to calculate these ratings, users can refer to the **Five-Star Quality Rating System Technical Users' Guide** and visit the **Nursing Home Care Compare** website for comparisons of nursing homes in their area.

# %%
#pip install pdfplumber
# !pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (1.69.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from openai) (4.13.0)
# Requirement already satisfied: idna>=2.8 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: colorama in c:\users\rakad\anaconda3\envs\llms\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
# Read pdf
import requests
from bs4 import BeautifulSoup
import pdfplumber
from io import BytesIO

class Website:
    def __init__(self, url):
        response = requests.get(url, stream=True)  # Stream to avoid memory issues

        # Check if the content is a PDF
        if "application/pdf" in response.headers.get("Content-Type", ""):
            pdf_file = BytesIO(response.content)  # Convert bytes to file-like object
            with pdfplumber.open(pdf_file) as pdf:
                self.text = "\n".join([page.extract_text() for page in pdf.pages if page.extract_text()])
            self.title = "PDF Document"
        else:
            soup = BeautifulSoup(response.content, 'html.parser')
            self.title = soup.title.string if soup.title else "No title found"
            if soup.body:  
                for irrelevant in soup.body(["script", "style", "img", "input"]):
                    irrelevant.decompose()
                self.text = soup.body.get_text(separator="\n", strip=True)
            else:
                self.text = "No readable content found."

# %%
# Example Usage
website = Website("https://files.tablegroup.com/wp-content/uploads/2020/12/11224029/FiveDysfunctions.pdf")
print(website.text[:500])  # Print first 500 characters

# %%
import openai

# Initialize OpenAI client
client = openai.OpenAI()

def summarize_text(text):
    """Summarizes given text using OpenAI API (new v1.0+ format)."""
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "Summarize the following text:"},
            {"role": "user", "content": text}
        ]
    )
    return response.choices[0].message.content

# %%
#read pdf from local 

import pdfplumber
import re
import openai

def extract_text_from_pdf(file_path):
    """Extracts text from a local PDF file."""
    with pdfplumber.open(file_path) as pdf:
        text = "\n".join([page.extract_text() for page in pdf.pages if page.extract_text()])
    return text

def split_into_chapters(text):
    """Splits text into chapters and sections."""
    chapter_pattern = re.compile(r"(Chapter\s+\d+.*)", re.IGNORECASE)
    section_pattern = re.compile(r"(Section\s+\d+:.*)", re.IGNORECASE)

    matches = list(chapter_pattern.finditer(text))
    chapters = {}

    for i in range(len(matches)):
        start = matches[i].start()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        chapter_title = text[start:matches[i].end()].strip()
        chapter_content = text[start:end].strip()

        # Split into sections inside the chapter
        sections = {}
        section_matches = list(section_pattern.finditer(chapter_content))

        if section_matches:
            for j in range(len(section_matches)):
                s_start = section_matches[j].start()
                s_end = section_matches[j + 1].start() if j + 1 < len(section_matches) else len(chapter_content)
                section_title = chapter_content[s_start:section_matches[j].end()].strip()
                section_text = chapter_content[s_start:s_end].strip()
                sections[section_title] = section_text
        else:
            sections["Full Chapter"] = chapter_content  # No sections, store full text

        chapters[chapter_title] = sections

    return chapters

def summarize_text(text):
    """Summarizes given text using OpenAI API."""
    response = openai.ChatCompletion.create(
        model="gpt-4o",
        messages=[{"role": "system", "content": "Summarize the following text:"},
                  {"role": "user", "content": text}]
    )
    return response["choices"][0]["message"]["content"]

def summarize_chapters(file_path):
    """Extracts and summarizes chapters & sections from a local PDF."""
    text = extract_text_from_pdf(file_path)
    chapters = split_into_chapters(text)
    summaries = {}

    for chapter, sections in chapters.items():
        summaries[chapter] = {}
        for section, content in sections.items():
            summaries[chapter][section] = summarize_text(content)

    return summaries

# %%
# Example Usage
file_path = r"C:\Users\rakad\Downloads\mds-3.0-qm-users-manual-v17.0.pdf"  # Update path
chapter_summaries = summarize_chapters(file_path)

# Print first few summaries
for chapter, sections in chapter_summaries.items():
    print(f"\n{chapter}:")
    for section, summary in sections.items():
        print(f"\n  {section}:\n  {summary[:500]}...")  # Print first 500 characters
# Out:
# Chapter 1 QM Sample and Record Selection Methodology ......................................................1:
#
#   Section 1: Definitions .......................................................................................................2:
#   The document provides information about the definitions section, which begins on page 2....
#
#   Section 2: Selecting the QM Samples ...............................................................................5:
#   The text is likely outlining the table of contents for a document, with Section 2 focusing on the topic of selecting QM (Quality Management) samples, possibly found on page 5....
#
#   Section 3: Short-Stay Record Definitions .........................................................................6:
#   This section likely contains definitions related to short-stay records, starting on page 6....
#
#   Section 4: Long-Stay Record Definitions .........................................................................8:
#   The document contains a section labeled "Section 4: Long-Stay Record Definitions" beginning on page 8, which likely discusses the criteria or parameters for defining long-term stay records....
#
#   Section 5: Transition from MDS 3.0 V1.18.11 to MDS 3.0 V1.19.1 .............................11:
#   Section 5 discusses the transition from MDS 3.0 Version 1.18.11 to MDS 3.0 Version 1.19.1....
#
# Chapter 2 MDS 3.0 Quality Measures Logical Specifications ................................................12:
#
#   Section 1: Short Stay (SS) Quality Measures .................................................................13:
#   The text provides a list of tables related to Short Stay (SS) Quality Measures in healthcare, focusing on various aspects such as skin integrity post-care, influenza and pneumococcal vaccination rates, and the use of antipsychotic medication. It details the percentage of residents assessed and vaccinated appropriately, those who were offered and declined vaccines, and those who did not receive vaccines due to medical contraindications. Additionally, it includes a table on discharge function scores. The information is part of the MDS 3.0 Quality Measures User's Manual, set to be effective from January 1, 2025....
#
#   Section 2: Long-Stay (LS) Quality Measures .................................................................24:
#   The text is a table of contents for Section 2 of a manual focusing on Long-Stay (LS) Quality Measures. It includes tables that provide percentages of residents experiencing various health and care conditions, such as falls with major injury, vaccine administration, urinary tract infections, catheter use, physical restraint, weight loss, depressive symptoms, and medication use. Additionally, it addresses issues like a decline in the ability to perform daily activities, pressure ulcers, incontinence, and prevalence of behavior symptoms affecting others. This information is from the MDS 3.0 Quality Measures User’s Manual V17, effective from January 1, 2025....
#
# Chapter 3 Quality Measures (QM) Technical Details .............................................................49:
#
#   Section 1: Introduction ....................................................................................................50:
#   This text indicates that the information provided is based on data available up to October 2023, and references an introduction section that starts on page 50....
#
#   Section 2: Steps Used in National QM Calculation ........................................................51:
#   You were trained on data available up to October 2023, specifically focusing on the section about the steps used in National QM Calculation mentioned on page 51....
#
#   Section 3: Calculation of the Expected QM Score .........................................................55:
#   This section, found on page 55, outlines the methodology for calculating the Expected QM Score, likely detailing the steps or formulae required for this specific evaluation....
#
#   Section 4: Calculation of the Adjusted QM Score ..........................................................57:
#   Section 4 is focused on the process and methodology for calculating the Adjusted QM (Quality Management) Score, found on page 57....
#
#   Section 5: Risk-Adjustment Appendix Overview...........................................................58:
#   This section of the document provides an overview of the Risk-Adjustment Appendix, which begins on page 58....
#
# Chapter 4 Episode and Stay Determination Logic ...................................................................60:
#
#   Full Chapter:
#   The text references a section from a document, specifically "Chapter 4 Episode and Stay Determination Logic," starting on page 60, and includes "Table 4-1 Possible Entry Dates When Entry Record is Missing" on page 63....
#
# Chapter 5 Specifications for the Facility Characteristics Report .............................................67:
#
#   Full Chapter:
#   The text provides information on the Facility Characteristics Report from Chapter 5, detailing specifications and measure definitions starting from page 67. It includes tables of Quality Measures categorized by CMS Reporting Module for both short and long stays. The MDS 3.0 Quality Measures User’s Manual V17, effective January 1, 2025, notes changes, including revised guidance on selecting MDS Section GG item columns for measure calculations, clarifying that Section GG item values are based on the target or prior assessment's qualifying reasons for assessment. Additional guidance is provided for scenarios where there are multiple qualifying RFAs, though these updates will not significantly affect measure calculations....
#
# Chapter 1, Section 3 and Chapter 1, Section 4 for more information on the qualifying RFAs for target and prior:
#
#   Full Chapter:
#   The text refers to sections in a manual relevant to qualifying RFAs (Request for Applications) for target and prior assessments. It mentions that the Quality Measures User’s Manual, Version 17 of MDS 3.0, will be effective from January 1, 2025....
#
# Chapter 1:
#
#   Full Chapter:
#   Chapter 1 of the MDS 3.0 Quality Measures User’s Manual V17, effective January 1, 2025, explains the methodology for selecting short- and long-stay samples and key records used to compute QMs for these samples. It includes definitions used in the selection process and describes how the samples and key records within each are chosen. The methodology relies on understanding stays and episodes, with detailed specifications provided elsewhere in the manual....
#
# Chapter 4 of this:
#
#   Full Chapter:
#   I apologize, but it seems that the initial prompt is missing or incomplete. Could you please provide more information or context about Chapter 4?...
#
# Chapter 4 apply to:
#
#   Section 1: Definitions:
#   As of October 2023, the definitions provided apply specifically to residents with clearly defined assessment data streams. For additional guidelines on identifying stays and episodes of care when the data stream is not well-defined, more information is available....
#
# Chapter 4.:
#
#   Section 2: Selecting the QM Samples:
#   The process for selecting Quality Measure (QM) samples involves two categories: short-stay and long-stay residents. The selection starts by identifying all residents whose most recent episode ends or is ongoing at the target period's end. The duration, known as CDIF, is calculated for each episode. Residents with a CDIF of 100 days or less are categorized as short-stay, while those with more than 100 days as long-stay. Each resident can only be classified into one of the two mutually exclusive samples. If a resident has multiple episodes during the target period, only their latest is considered. Key records within each sample are used later for calculating individual measures....
#
#   Section 3: Short-Stay Record Definitions:
#   The document outlines definitions and selection criteria for short-stay records used in assessment processes, focusing on the selection periods and qualifying criteria for various assessments, such as Target, Initial, Look-back Scan, and Influenza Vaccination Assessments. It uses specified RFA codes to determine qualifying records. The rationale provided ensures the inclusion of necessary items for quality measures, with specific timeframes (e.g., 120, 130 days) and target dates for assessments, allowing for late submissions and considering episodes of care. These criteria help identify key resident status updates and event occurrences during specific periods, such as the influenza season, within care facilities....
#
#   Section 4: Long-Stay Record Definitions:
#   The text outlines the long-stay record selection criteria for assessments in the MDS 3.0 Quality Measures User’s Manual V17, effective January 1, 2025. It details the requirements for selecting target, prior, and look-back assessments based on specific criteria such as qualifying RFAs and target dates. The selection process includes a focus on long-stay residents' episodes and the timing of assessments, allowing for quarterly intervals and providing measures for evaluating resident conditions and events over a year-long timeframe. Additionally, it includes criteria for selecting influenza vaccination assessments within the defined influenza season....
#
#   Section 5: Transition from MDS 3.0 V1.18.11 to MDS 3.0 V1.19.1:
#   The transition from MDS 3.0 version 1.18.11 to version 1.19.1 takes effect on October 1, 2024. This change does not impact any of the NHQI quality measures. The MDS 3.0 Quality Measures User’s Manual version 17 will be effective starting January 1, 2025....
#
# Chapter 2:
#
#   Section 1: Short Stay (SS) Quality Measures:
#   The Short Stay (SS) Quality Measures section discusses the measure "Changes in Skin Integrity Post-Acute Care: Pressure Ulcer/Injury" (CMS ID: S038.02), which is part of the SNF Quality Reporting Program. This measure's logic specifications are detailed in the SNF Quality Reporting Program Measure Calculations and Reporting User’s Manual V6.0 available on the SNF QRP website under the Downloads section....
#
# Chapter 8, Table 8-3.:
#
#   Full Chapter:
#   The text describes various quality measures detailed in the MDS 3.0 Quality Measures User's Manual V17, effective January 1, 2025. It includes measures for the assessment and administration of seasonal influenza and pneumococcal vaccines to short-stay residents, as well as the use of antipsychotic medications and the discharge function score, used in the Five-Star Quality Rating System. Each measure provides specifications for its numerator and denominator, exclusions, and notes on calculation frequency and timeframe. The MDS 3.0 manual and related resources are found on the CMS website for further details....
#
# Chapter 8, Table 8-8.:
#
#   Section 2: Long-Stay (LS) Quality Measures:
#   The document provides detailed specifications for multiple long-stay (LS) quality measures applicable to long-term healthcare facilities, effective January 1, 2025. These measures include data on residents experiencing falls with major injury, influenza and pneumococcal vaccinations, urinary tract infections, catheter usage, physical restraint, help with activities of daily living, weight loss, depression symptoms, antipsychotic and antianxiety medication use, pressure ulcers, incontinence, and bed mobility. Each measure includes criteria for the numerator and denominator, relevant exclusions, and notes if covariates apply. The measures are intended to provide benchmarks for evaluating the quality of care in these facilities and are part of the Five-Star Quality Rating System utilized for assessments and reporting....
#
# Chapter 3:
#
#   Section 1: Introduction:
#   this section. The chapter then delves into how these measures are adjusted for risk to ensure accurate comparisons between facilities with different resident populations. This involves using statistical techniques to account for varying factors that might affect the outcomes, such as patient demographics and health status. The process allows for a fair assessment of the quality of care provided by the nursing facilities, ensuring the evaluations are equitable and reflect genuine differences in performance....
#
# Chapter 1: QM Sample and Record:
#
#   Full Chapter:
#   The text seems to be the beginning of a document titled "Chapter 1: QM Sample and Record Selection Methodology", likely pertaining to Quality Management (QM). However, the provided text is incomplete and does not provide further information or context regarding its contents....
#
# Chapter 2: Quality Measures Logical Specifications of this:
#
#   Section 2: Steps Used in National QM Calculation:
#   The text provides a detailed outline of the steps involved in calculating Quality Measures (QMs) for US nursing facilities, using data for Q1 2024 as the target period. It mentions that the process involves parallel steps for "Long stay" (LS) and "Short stay" (SS) samples. Key steps include MDS selection, episode creation, resident sampling for both LS and SS QMs, resident-level QM calculations, logistic regressions for risk-adjusted QMs, and calculations of national mean QMs. Finally, it describes how facility-level observed, expected, and adjusted QM scores are calculated and reported, particularly focusing on the risk-adjusted QMs. The process ensures that the QM calculations account for facility-specific and national benchmarks for quality assessment in nursing facilities....
#
#   Section 3: Calculation of the Expected QM Score:
#   The text provides a detailed explanation of calculating the resident-level expected Quality Measure (QM) score, which is an estimate of the risk that a resident will trigger a specific QM. This calculation involves using resident-level covariates and logistic regression to account for risk adjustment. The process uses equations to determine expected scores based on whether residents trigger specific covariates, such as bowel incontinence and pressure ulcers. The example given calculates expected scores for a QM related to catheter use, demonstrating the effect of resident conditions on expected outcomes. The facility-level expected QM score is derived by averaging the resident-level scores for the QMs....
#
#   Section 4: Calculation of the Adjusted QM Score:
#   The text outlines the process for calculating the risk-adjusted QM score, which is a measurement adjusted for facility-specific risks in nursing facilities. This score estimates a facility's QM rate assuming its residents have average risk. The calculation involves the facility-level observed QM score, the facility-level average expected QM score, and the national average observed QM score. A specific formula using natural logarithms adjusts these scores. Special cases in the equation are addressed when the observed QM rate equals 0.00 or 1.00. The adjusted QM scores range from 0 to 1 and can be converted to percentages for easier interpretation. The process applies to QMs using expected scores based on resident-level covariates, with necessary data available in the Risk-Adjustment Appendix File....
#
#   Section 5: Risk-Adjustment Appendix Overview:
#   The Risk-Adjustment Appendix Overview provides details on the intercept and logistic regression coefficient values used in risk-adjusted quality measures (QMs). These are available in the Risk-Adjustment Appendix File on the NHQI website, containing current and historical values and the risk-adjustment schedule with applicable discharge dates. The Excel worksheets in the Appendix File include an overview, the risk-adjustment schedule, full and abbreviated measure names, update IDs, manual specification versions, posting dates, and assessment dates for each update. The National Average tab shows observed scores for each update, noting that national averages in public reports may differ. Quality Measure Specific Tabs list covariates and coefficient values, effective January 1, 2025....
#
# Chapter 4:
#
#   Full Chapter:
#   Chapter 4 of the MDS 3.0 Quality Measures User’s Manual V17, effective January 1, 2025, details the logic for determining episodes and stays in the CMS applications based on MDS 3.0 data. It defines stays as the duration a resident is in a facility, while episodes are built from one or more stays. The chapter provides comprehensive rules for identifying stays and episodes, handling exceptional cases like missing entry or discharge records, and sorting records effectively. Key aspects include determining the start, end dates, and types (admission or reentry) of stays, rules for constructing a well-organized data stream, and strategies for imputing missing records or sorting multiple records....
#
# Chapter 5:
#
#   Full Chapter:
#   Chapter 5 of the MDS 3.0 Quality Measures User’s Manual V17, effective from January 1, 2025, outlines specifications for the Facility Characteristics Report. This report is developed using data from records selected according to standard QM episode and record selection logic. Various measures regarding Facility Characteristics, such as gender, age, ethnicity, race, diagnostic characteristics, and more, are defined within the manual. The report utilizes data from a look-back scan of assessment records and provides facility percentages based on the numerator and denominator criteria for each measure. Definitions include categories such as gender, age ranges, ethnicity, race, psychiatric diagnoses, intellectual disabilities, hospice, prognosis, discharge planning, referrals, type of entry, and facility entry sources. Appendix A details the Quality Measure Identification Number by CMS Reporting Module, outlining how these measures are calculated and reported in CMS quality reporting modules like the iQIES, Care Compare, and Five-Star Quality Rating System....
#
# Chapter 2 of this user’s manual.:
#
#   Full Chapter:
#   The text contains information from Chapter 2 of the "MDS 3.0 Quality Measures User’s Manual V17," which becomes effective on January 1, 2025. It lists quality measures (QMs) relevant to short stay and long stay residents in healthcare facilities, highlighting details such as CMS ID, iQIES availability, and Five-Star Preview status. The tables categorize various quality measures based on aspects like skin integrity, vaccine administration, medication use, falls, urinary tract infections, and more, with specific notes on endorsement status and effective dates. These reports are accessible to facilities and state surveyors for evaluation and compliance monitoring....

# %%
display_summary("https://files.tablegroup.com/wp-content/uploads/2020/12/11224029/FiveDysfunctions.pdf")
# Out:
# # Summary of "The Five Dysfunctions of a Team"
#
# The website discusses **Patrick Lencioni's model** outlining the five key dysfunctions that can hinder team performance and cohesion within organizations:
#
# 1. **Absence of Trust**: Team members' fear of vulnerability prevents the establishment of trust.
# 2. **Fear of Conflict**: Hesitance to engage in healthy debate leads to unproductive meetings and decisions.
# 3. **Lack of Commitment**: When team members are not aligned on goals, it causes indecision and a lack of direction.
# 4. **Avoidance of Accountability**: Without clear commitments, team members hesitate to hold each other accountable for their contributions.
# 5. **Inattention to Results**: Focusing on personal goals over team outcomes detracts from collective success.
#
# **Key Insights**: The text emphasizes that all teams can be dysfunctional to some extent, but with courage and discipline, these dysfunctions can be addressed. Functional teams result in better productivity, decision-making, and employee retention.
#
# ### About the Author
# **Patrick Lencioni** is the founder of the Table Group and has authored several best-selling books on team dynamics and organizational health. He has extensive experience consulting with both for-profit and nonprofit organizations.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
# Step 1: Create your prompts

system_prompt = "something here"
user_prompt = """
    Lots of text
    Can be pasted here
"""

# Step 2: Make the messages list

messages = [] # fill this in

# Step 3: Call OpenAI

response =

# Step 4: print the result

print(

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then GPT has given some nice instructions on how to submit a Pull Request. It's a bit of an involved process, but once you've done it once it's pretty clear. As a pro-tip: it's best if you clear the outputs of your Jupyter notebooks (Edit >> Clean outputs of all cells, and then Save) for clean notebooks.
#
# Here are good instructions courtesy of an AI friend:
# https://chatgpt.com/share/677a9cb5-c64c-8012-99e0-e06e88afd293
